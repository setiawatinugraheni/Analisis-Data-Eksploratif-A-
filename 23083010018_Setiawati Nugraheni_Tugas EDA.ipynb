# %% [markdown]
# #  Dataset Ujian Nasional

# %% [markdown]
# ### Nama : Setiawati Nugraheni
# ### NPM : 23083010018

# %% [markdown]
# ##### Dataset ini dibuat secara simulasi untuk memberikan contoh latihan dalam pelatihan machine learning. Dataset terdiri dari 100 entri yang merekam rekam jejak nilai mahasiswa dalam berbagai mata kuliah.
#
# Setiap entri dalam dataset ini mencakup informasi berikut:
#
# Nama Siswa: Nama lengkap dari mahasiswa yang tercatat dalam dataset. Nama-nama ini dibuat secara acak dan tidak berkaitan dengan individu nyata.
#
# Mata Kuliah: Nama mata kuliah yang diambil oleh mahasiswa. Ini mencakup berbagai jenis mata kuliah, seperti Matematika, Fisika, Bahasa Inggris, Sejarah, dan lain-lain.
#
# Nilai: Nilai yang diperoleh oleh mahasiswa dalam mata kuliah tertentu. Nilai ini dalam bentuk numerik dan mencerminkan kinerja akademik mahasiswa dalam mata kuliah tersebut.
#
# Dataset ini dibuat sebagai contoh untuk latihan machine learning, dan nilai-nilai yang terdapat di dalamnya bersifat fiktif. Tujuannya adalah untuk memberikan pemahaman tentang bagaimana data dapat diorganisir dalam konteks machine learning, serta bagaimana model dapat dilatih untuk memprediksi atau menganalisis hubungan antara nilai, nama siswa, dan mata kuliah.
#
# Dataset ini tidak memiliki tujuan akademik atau klinis yang sebenarnya. Semua data bersifat fiksi dan tidak mencerminkan prestasi sebenarnya dari individu yang nyata. Digunakan hanya untuk keperluan pembelajaran dan eksperimen dalam bidang machine learning.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv ("C:/Users/hani/Downloads/Dataset Pelatihan.csv")
data.head()
# Out:
#     ID  Nama  Umur     Gender  Nilai      Matkul    Tanggal   UTS   UAS
# 0  1.0  Budi  24.0  Laki-laki   85.0       Kimia   9/8/2023  90.0  80.0
# 1  2.0   Ani  21.0  Perempuan   77.5  Matematika  15/8/2023  75.0  80.0
# 2  3.0  Joko  20.0  Laki-laki   90.0     Biologi  15/8/2023  85.0  95.0
# 3  4.0  Siti  21.0  Perempuan   60.0  Matematika   9/8/2023  55.0  65.0
# 4  5.0  Agus  23.0  Laki-laki   77.5      Fisika   9/8/2023  80.0  75.0

# %%
data['Matkul'].value_counts()
# Out:
# Matematika    26
# Kimia         25
# Biologi       25
# Fisika        24
# Name: Matkul, dtype: int64

# %%
np.sum(data.isnull())
# Out:
# ID         10
# Nama       10
# Umur       10
# Gender     10
# Nilai      10
# Matkul     10
# Tanggal    10
# UTS        10
# UAS        10
# dtype: int64

# %%
data['ID'].fillna("None", inplace=True)
data['Nama'].fillna("None", inplace=True) 
data['Umur'].fillna("None", inplace=True) 
data['Gender'].fillna("None", inplace=True) 
data['Nilai'].fillna("None", inplace=True) 
data['Matkul'].fillna("None", inplace=True) 
data['Tanggal'].fillna("None", inplace=True) 
data['UTS'].fillna("None", inplace=True) 
data['UAS'].fillna("None", inplace=True) 

np.sum(data.isnull())
# Out:
# ID         0
# Nama       0
# Umur       0
# Gender     0
# Nilai      0
# Matkul     0
# Tanggal    0
# UTS        0
# UAS        0
# dtype: int64

# %%
datacopy=data.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       110 non-null    object
#  1   Nama     110 non-null    object
#  2   Umur     110 non-null    object
#  3   Gender   110 non-null    object
#  4   Nilai    110 non-null    object
#  5   Matkul   110 non-null    object
#  6   Tanggal  110 non-null    object
#  7   UTS      110 non-null    object
#  8   UAS      110 non-null    object
# dtypes: object(9)
# memory usage: 7.9+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       110 non-null    object
#  1   Nama     110 non-null    object
#  2   Umur     110 non-null    object
#  3   Gender   110 non-null    object
#  4   Nilai    110 non-null    object
#  5   Matkul   110 non-null    object
#  6   Tanggal  110 non-null    object
#  7   UTS      110 non-null    object
#  8   UAS      110 non-null    object
# dtypes: object(9)
# memory usage: 7.9+ KB

# %%
data.head()
# Out:
#     ID  Nama  Umur     Gender Nilai      Matkul    Tanggal   UTS   UAS
# 0  1.0  Budi  24.0  Laki-laki  85.0       Kimia   9/8/2023  90.0  80.0
# 1  2.0   Ani  21.0  Perempuan  77.5  Matematika  15/8/2023  75.0  80.0
# 2  3.0  Joko  20.0  Laki-laki  90.0     Biologi  15/8/2023  85.0  95.0
# 3  4.0  Siti  21.0  Perempuan  60.0  Matematika   9/8/2023  55.0  65.0
# 4  5.0  Agus  23.0  Laki-laki  77.5      Fisika   9/8/2023  80.0  75.0

# %%
print(data.dtypes)
# Out:
# ID         object
# Nama       object
# Umur       object
# Gender     object
# Nilai      object
# Matkul     object
# Tanggal    object
# UTS        object
# UAS        object
# dtype: object

# %%
import numpy as np
import pandas as pd

# Mengonversi kolom 'Umur' menjadi numeric dan mengganti nilai non-numerik dengan NaN
data['Umur'] = pd.to_numeric(data['Umur'], errors='coerce')
data['Umur'] = data['Umur'].fillna(0).astype(np.int64)  # Mengganti NaN dengan 0, atau bisa disesuaikan

# Menampilkan tipe data
print(data.dtypes)
# Out:
# ID         object
# Nama       object
# Umur        int64
# Gender     object
# Nilai      object
# Matkul     object
# Tanggal    object
# UTS        object
# UAS        object
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Membuat 1 subplot (1 kolom, 1 baris)
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))  # Hanya ada satu axes

# Mengatur feature_index untuk memilih kolom pertama (atau kolom yang diinginkan)
feature_index = 0
if feature_index < len(data_cont.columns):
    sns.boxplot(x=data_cont.iloc[:, feature_index], ax=ax)  # Gunakan langsung 'ax'
    ax.set(title=data_cont.columns.values[feature_index])

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Misalnya, data['Gender'] adalah sebuah pandas Series
# Gender categories
data1 = {'Gender': ['Male', 'Female', 'Female', 'Male', 'Male']}
df = pd.DataFrame(data)

f, ax = plt.subplots(1, 2, figsize=(18, 8))

# Hitung jumlah kategori
gender_counts = df['Gender'].value_counts()
num_categories = len(gender_counts)

# Sesuaikan panjang explode
explode = [0] * num_categories  # Daftar explode dengan nilai 0
if num_categories > 1:
    explode[1] = 0.1  # Misalnya, meledakkan kategori kedua hanya jika ada lebih dari 1 kategori

# Plot pie chart
gender_counts.plot.pie(explode=explode, autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Gender')
ax[0].set_ylabel('')

gender_counts.plot.bar(ax=ax[1], color=['blue', 'orange'])
ax[1].set_title('Gender (Bar Chart)')
ax[1].set_xlabel('Gender')
ax[1].set_ylabel('Count')

# Tampilkan plot
plt.tight_layout()
plt.show()

# %%
print(data)
# Out:
#        ID  Nama  Umur     Gender Nilai      Matkul    Tanggal   UTS   UAS
# 0     1.0  Budi    24  Laki-laki  85.0       Kimia   9/8/2023  90.0  80.0
# 1     2.0   Ani    21  Perempuan  77.5  Matematika  15/8/2023  75.0  80.0
# 2     3.0  Joko    20  Laki-laki  90.0     Biologi  15/8/2023  85.0  95.0
# 3     4.0  Siti    21  Perempuan  60.0  Matematika   9/8/2023  55.0  65.0
# 4     5.0  Agus    23  Laki-laki  77.5      Fisika   9/8/2023  80.0  75.0
# ..    ...   ...   ...        ...   ...         ...        ...   ...   ...
# 105  None  None     0       None  None        None       None  None  None
# 106  None  None     0       None  None        None       None  None  None
# 107  None  None     0       None  None        None       None  None  None
# 108  None  None     0       None  None        None       None  None  None
# 109  None  None     0       None  None        None       None  None  None
#
# [110 rows x 9 columns]

# %%
sns.countplot(y=data["Matkul"], hue=data["Gender"])
plt.show()
sns.countplot(y=data["UTS"], hue=data["Gender"])
plt.show()
sns.countplot(y=data["UAS"], hue=data["Gender"])
plt.show()

# %%
sns.distplot(data["Umur"])
plt.show()
# Out:
# C:\Users\hani\AppData\Local\Temp\ipykernel_5428\3699645771.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Umur"])

# %%
sns.heatmap(data.corr(),linewidths=.5,annot=True,cmap='RdYlGn')
fig=plt.gcf()
fig.set_size_inches(15,8)
plt.show()
# Out:
# C:\Users\hani\AppData\Local\Temp\ipykernel_5428\2282208908.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),linewidths=.5,annot=True,cmap='RdYlGn')
